# %% [markdown]
# <a href="https://colab.research.google.com/github/ElvisNarciso/Calculadora/blob/main/Livro4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# %cd /content/text-generation-webui
# !chmod +x start_linux.sh
#
# #Rodar o script para iniciar o WebUI
# !bash start_linux.sh --share

# %%
# !chmod +x start_linux.sh

# Rodar o script para iniciar o WebUI
# !bash start_linux.sh --share
# Out:
# *******************************************************************
# * You haven't downloaded any model yet.
# * Once the web UI launches, head over to the "Model" tab and download one.
# *******************************************************************
#
#
# 20:25:22-625004 INFO     Starting Text generation web UI
#
# Running on local URL:  http://127.0.0.1:7860
#
# Running on public URL: https://3963bae0da7ace18b4.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Closing server running on port: 7860
# 20:26:46-385453 INFO     Loading the extension "coqui_tts"
# [XTTS] Loading XTTS...
#  > Downloading model to /root/.local/share/tts/tts_models--multilingual--multi-dataset--xtts_v2
# 100% 1.86G/1.87G [00:44<00:00, 42.6MiB/s]
# 100% 1.87G/1.87G [00:44<00:00, 42.0MiB/s]
# 100% 4.37k/4.37k [00:00<00:00, 16.9kiB/s]
# ...
